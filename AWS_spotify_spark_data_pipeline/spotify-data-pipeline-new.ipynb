# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '5f54ff961cbf41608b9c6eb7d7613e05', client_secret = '49622debd6274f2db7f52db6dad72de3')

# %%
spotipy = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

playlist_uri = playlist_link.split("/")[-1].split('?')[0]

# %%
data = spotipy.playlist_tracks(playlist_uri)
# print(data)

# %%
data['items'][0]
# Out:
# {'added_at': '2024-10-11T12:30:50Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#    'id': '10FLjwfpbxLmW8c25Xyc2N',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#      'width': 64}],
#    'name': 'Die With A Smile',
#    'release_date': '2024-08-16',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 251667,
#   'external_ids': {'isrc': 'USUM72409273'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#   'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#   'id': '2plbrEY59IikOBgBGLjaoe',
#   'name': 'Die With A Smile',
#   'popularity': 100,
#   'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row["track"]["album"]['external_urls']['spotify']
    album_element = { 'album_id': album_id, 'name': album_name, 'release_date': album_release_date, 'total_tracks': album_total_tracks, 'url': album_url}
    album_list.append(album_element)

# %%
album_list[0:2]
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'}]

# %%
artist_info = []
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artists_info = spotipy.artist(artist['id'])
                artist_dict = {"artist_id": artist['id'], "artist_name": artist['name'], 'artist_genres': ', '.join(artists_info['genres']), 
                               'followers': artists_info['followers']['total'], 'popularity': artists_info['popularity'], 'external_uri': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list[0:2]
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_genres': 'art pop, dance pop, pop',
#   'followers': 32062017,
#   'popularity': 92,
#   'external_uri': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'artist_genres': 'dance pop, pop',
#   'followers': 60240128,
#   'popularity': 94,
#   'external_uri': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'}]

# %%
song_list = []

for row in data['items']:
    artist_ids = []
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    if len(row['track']['artists']) > 1:
        for artist in row['track']['artists']:
            artist_ids.append(artist['id'])
    else: 
        artist_ids.append(row['track']['artists'][0]['id'])
    song_element = { "song_id": song_id, "song_name": song_name, "song_duration": song_duration, "song_url": song_url,
                   "song_popularity": song_popularity, "song_added": song_added, "album_id": album_id, "artist_id": ', '.join(artist_ids)}
    song_list.append(song_element)

# %%
song_list[0:2]
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'song_duration': 251667,
#   'song_url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'song_popularity': 100,
#   'song_added': '2024-10-11T12:30:50Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms, 0du5cEVh5yTK9QJze8zA0C'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'song_duration': 210373,
#   'song_url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'song_popularity': 98,
#   'song_added': '2024-10-11T12:30:50Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
# 3  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
# 4  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 3  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 4  https://open.spotify.com/album/3iPSVi54hsacKKl...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], format='mixed')
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     datetime64[ns]
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
# 3  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
# 5  1WAjjRMfZjEXtB0lQrAw6Q      Good Luck, Babe!   2024-04-05             1
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 3  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 5  https://open.spotify.com/album/1WAjjRMfZjEXtB0...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id        artist_name            artist_genres  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga  art pop, dance pop, pop
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars           dance pop, pop
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish             art pop, pop
# 3  1oSPZhvZMIrWW5I41kPkkY              Jimin                    k-pop
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter                      pop
#
#    followers  popularity                                       external_uri
# 0   32062017          92  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1   60240128          94  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  100730714          96  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3    9594753          89  https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 4   13640801          95  https://api.spotify.com/v1/artists/74KM79TiuVK...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist_id      67 non-null     object
#  1   artist_name    67 non-null     object
#  2   artist_genres  67 non-null     object
#  3   followers      67 non-null     int64
#  4   popularity     67 non-null     int64
#  5   external_uri   67 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 3.3+ KB

# %%
artist_df.drop_duplicates(subset=['artist_id'])
# Out:
#                  artist_id         artist_name  \
# 0   1HY2Jd0NmPuamShAr6KMms           Lady Gaga
# 1   0du5cEVh5yTK9QJze8zA0C          Bruno Mars
# 2   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish
# 3   1oSPZhvZMIrWW5I41kPkkY               Jimin
# 4   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter
# 6   7GlBOeep6PqTfFi59PTUUN       Chappell Roan
# 7   1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd
# 2                                        art pop, pop  100730714          96
# 3                                               k-pop    9594753          89
# 4                                                 pop   13640801          95
# 6                                           indie pop    3493917          90
# 7        canadian contemporary r&b, canadian pop, pop   92653983          96
# 8          atl hip hop, plugg, pluggnb, rage rap, rap   11942418          90
# 9      reggaeton, reggaeton colombiano, urbano latino   51103610          92
# 11                              singer-songwriter pop    3726066          86
# 12                                        bedroom pop     321271          77
# 15           trap boricua, trap latino, urbano latino     345028          81
# 16                         trap latino, urbano latino     204861          78
# 17                        modern country pop, pop rap     718714          81
# 18          modern alternative rock, modern rock, pop   18155594          86
# 19  alternative metal, nu metal, post-grunge, rap ...   27135709          92
# 20  irish singer-songwriter, modern rock, pop, pov...    7932348          87
# 21                                              alt z    2680237          86
# 23                                              k-pop    7429040          81
# 24                                                pop     186374          77
# 25  garage rock, modern rock, permanent wave, rock...   26886745          87
# 26                                              k-pop    9181457          83
# 27                                                       3168976          86
# 28                                    rap, slap house   33635798          94
# 30                                            corrido    1779776          89
# 31                                  reggaeton chileno     985395          85
# 32                     dfw rap, melodic rap, pop, rap   45552431          92
# 33                               contemporary country   10853514          91
# 34                                        chill drill      90797          73
# 36  mambo chileno, trap latino, urbano chileno, ur...    3923987          88
# 37      art pop, candy pop, metropopolis, pop, uk pop    4259115          89
# 39                        pov: indie, psychedelic pop    1566750          76
# 40                                                pop  100385822          92
# 41                                   social media pop     395896          74
# 43                                       hip hop, rap   16522875          87
# 44                                      colombian pop    7950692          85
# 45                    corridos tumbados, sad sierreno   16635683          93
# 46                                            corrido     350935          82
# 47                       indie folk, stomp and holler    1731566          78
# 50                                              k-pop   16163380          87
# 51                                         trap queen    1788546          80
# 52  colombian pop, pop reggaeton, reggaeton, regga...   14206828          92
# 53                                                         46147          75
# 56                                                         11350          73
# 57                                                        956224          80
# 58    conscious hip hop, hip hop, rap, west coast rap   33469216          92
# 59                             chill abstract hip hop     731365          80
# 60                                                pop  123615685         100
# 61                              singer-songwriter pop     746643          79
# 62                                 australian hip hop    5743222          85
# 65                                            corrido    2602455          81
# 66  neo mellow, permanent wave, pop rock, post-grunge    2934387          76
#
#                                          external_uri
# 0   https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1   https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2   https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3   https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 4   https://api.spotify.com/v1/artists/74KM79TiuVK...
# 6   https://api.spotify.com/v1/artists/7GlBOeep6Pq...
# 7   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 8   https://api.spotify.com/v1/artists/699OTQXzgjh...
# 9   https://api.spotify.com/v1/artists/790FomKkXsh...
# 11  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 12  https://api.spotify.com/v1/artists/1iCnM8foFss...
# 15  https://api.spotify.com/v1/artists/3E12tRURRvP...
# 16  https://api.spotify.com/v1/artists/54seKvtsZau...
# 17  https://api.spotify.com/v1/artists/3y2cIKLjiOl...
# 18  https://api.spotify.com/v1/artists/77SW9BnxLY8...
# 19  https://api.spotify.com/v1/artists/6XyY86QOPPr...
# 20  https://api.spotify.com/v1/artists/2FXC3k01G6G...
# 21  https://api.spotify.com/v1/artists/4tuJ0bMpJh0...
# 23  https://api.spotify.com/v1/artists/250b0Wlc5Vk...
# 24  https://api.spotify.com/v1/artists/1pBLC0qVRTB...
# 25  https://api.spotify.com/v1/artists/7Ln80lUS6He...
# 26  https://api.spotify.com/v1/artists/5L1lO4eRHmJ...
# 27  https://api.spotify.com/v1/artists/33qOK5uJ8AR...
# 28  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 30  https://api.spotify.com/v1/artists/5eumcnUkdmG...
# 31  https://api.spotify.com/v1/artists/7CvTknweLr9...
# 32  https://api.spotify.com/v1/artists/246dkjvS1zL...
# 33  https://api.spotify.com/v1/artists/4oUHIQIBe0L...
# 34  https://api.spotify.com/v1/artists/5HK6QtizXJz...
# 36  https://api.spotify.com/v1/artists/1Yj5Xey7kTw...
# 37  https://api.spotify.com/v1/artists/25uiPmTg16R...
# 39  https://api.spotify.com/v1/artists/5p9HO3XC5P3...
# 40  https://api.spotify.com/v1/artists/66CXWjxzNUs...
# 41  https://api.spotify.com/v1/artists/4gvjmrtzydb...
# 43  https://api.spotify.com/v1/artists/4V8LLVI7Pba...
# 44  https://api.spotify.com/v1/artists/1U1el3k54Vv...
# 45  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 46  https://api.spotify.com/v1/artists/6pV5zH2LzjO...
# 47  https://api.spotify.com/v1/artists/6ltzsmQQbmd...
# 50  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 51  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 52  https://api.spotify.com/v1/artists/2LRoIwlKmHj...
# 53  https://api.spotify.com/v1/artists/7jAs1uPnpfN...
# 56  https://api.spotify.com/v1/artists/6uzHLlGqFKa...
# 57  https://api.spotify.com/v1/artists/0PCCGZ0wGLi...
# 58  https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# 59  https://api.spotify.com/v1/artists/1WaFQSHVGZQ...
# 60  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 61  https://api.spotify.com/v1/artists/3bO19AOone0...
# 62  https://api.spotify.com/v1/artists/2tIP7SsRs7v...
# 65  https://api.spotify.com/v1/artists/2rmkQLzj0k4...
# 66  https://api.spotify.com/v1/artists/2sil8z5kiy4...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id           song_name  song_duration  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile         251667
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER         210373
# 2  7tI8dRuH2Yc6RuoTjxo4dU                 Who         170887
# 3  5G2f63n7IPVPPjfNIGih7Q               Taste         157279
# 4  2HRqTpkrJO5ggZyyK6NPWz            Espresso         175459
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...              100
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...               98
# 2  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...               93
# 3  https://open.spotify.com/track/5G2f63n7IPVPPjf...               95
# 4  https://open.spotify.com/track/2HRqTpkrJO5ggZy...               87
#
#              song_added                album_id  \
# 0  2024-10-11T12:30:50Z  10FLjwfpbxLmW8c25Xyc2N
# 1  2024-10-11T12:30:50Z  7aJuG4TFXa2hmE4z1yxc3n
# 2  2024-10-11T12:30:50Z  15XcLhiVMlSOipUddTNDnr
# 3  2024-10-11T12:30:50Z  3iPSVi54hsacKKl1xIR2eH
# 4  2024-10-11T12:30:50Z  3iPSVi54hsacKKl1xIR2eH
#
#                                         artist_id
# 0  1HY2Jd0NmPuamShAr6KMms, 0du5cEVh5yTK9QJze8zA0C
# 1                          6qqNVTkY8uBg9cP3Jd7DAH
# 2                          1oSPZhvZMIrWW5I41kPkkY
# 3                          74KM79TiuVKeVCqs8QtB0B
# 4                          74KM79TiuVKeVCqs8QtB0B

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_url         50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     object
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
song_df.drop_duplicates(subset=['song_id'])
# Out:
#                    song_id                                       song_name  \
# 0   2plbrEY59IikOBgBGLjaoe                                Die With A Smile
# 1   6dOtVTDdiauQNBQEDOtlAB                              BIRDS OF A FEATHER
# 2   7tI8dRuH2Yc6RuoTjxo4dU                                             Who
# 3   5G2f63n7IPVPPjfNIGih7Q                                           Taste
# 4   2HRqTpkrJO5ggZyyK6NPWz                                        Espresso
# 5   0WbMK4wrZ1wFSty9F7FCgu                                Good Luck, Babe!
# 6   1Es7AUAhQvapIcoh3qMKDL                   Timeless (with Playboi Carti)
# 7   6WatFBLVB0x077xWeoVc2k                    Si Antes Te Hubiera Conocido
# 8   2tHwzyyOLoWSFqYNjeVMzj                            Please Please Please
# 9   3xkHsmpQCBMytMJNiDf3Ii                                Beautiful Things
# 10  2262bWmqomIaJXwCRHr13j                                     Sailor Song
# 11  1UHS8Rf6h5Ar3CDWRd3wjF                                        Bed Chem
# 12  3QaPy1KgI7nu9FJEQUgn6h                                      WILDFLOWER
# 13  0Sr7ssScx54yxdM2ols7nW                   Q U E V A S H A C E R H O Y ?
# 14  5fZJQrFKWQLb7FpJXZ1g7K                              A Bar Song (Tipsy)
# 15  2QjOHCTQ1Jl3zawyYOpxh6                                 Sweater Weather
# 16  2PnlsTsOTLE5jnBnNe2K0A                           The Emptiness Machine
# 17  19XpFsce28aByvCC4g89tJ                                       Too Sweet
# 18  51rfRCiUSvxXlCSCfIztBy                           I Love You, I'm Sorry
# 19  7CyPwkp0oE8Ro9Dd5CUDjW  One Of The Girls (with JENNIE, Lily Rose Depp)
# 20  5XeFesFbtLpXzIVDNQP22n                                I Wanna Be Yours
# 21  3yDRcs0Y4pPzkvMbUfeF9H                                   Moonlit Floor
# 22  17phhZDn6oGtzMe56NuWvj                                    Lose Control
# 23  42VsgItocQwOQC3XWZ8JNA                      FE!N (feat. Playboi Carti)
# 24  6X6m4xmdFcz31p1h7Qg68c                                      EL LOKERON
# 25  42wdz3j7gstgUuhoFLCXqd                                       PELIGROSA
# 26  5IZXB5IKAD2qlvTPJYDCFB           I Had Some Help (Feat. Morgan Wallen)
# 27  0io16MKpbeDIdYzmGpQaES                                      Embrace It
# 28  2esZG2XFtuoWWA9AfDvSxy                                       Gata Only
# 29  0IsIY8pfu1yaGkPUD7pkDx                   Guess featuring billie eilish
# 30  3qhlB30KknSejmIvZZLjOD                                End of Beginning
# 31  51ZQ1vr10ffzbwIjDCwqm4        we can't be friends (wait for your love)
# 32  6MzofobZt2dm0Kf1hTThFz                                      Diet Pepsi
# 33  4xdBrk0nFZaP54vvZj0yx7                                      HOT TO GO!
# 34  7KA4W4McWYRpgf0fWsJZWB                See You Again (feat. Kali Uchis)
# 35  2aYZaN5SmkRDLsrrV8GkBQ                                     LA PATRULLA
# 36  3hRV0jL3vUpRrcy398teAU                                The Night We Met
# 37  5lKFO0PrOC9jmOlPEdjHsL                                        DOS DÍAS
# 38  2HRgqmZQC0MC7GeNuDIXHN             Seven (feat. Latto) (Explicit Ver.)
# 39  7bywjHOc0wSjGGbj04XbVi                                            LUNA
# 40  6PhRhocBXP4y7NpciGmzra                                 Después De La 1
# 41  3JG1uFc40wfyrqaWC7iv0e                      i like the way you kiss me
# 42  6AI3ezQ4o3HUoP6Dhudph3                                     Not Like Us
# 43  5AJ9hqTS2wcFQCELCFRO7A                             MILLION DOLLAR BABY
# 44  1BxfuPKGuaTgP7aM0Bbdwr                                    Cruel Summer
# 45  3Vr3zh0r7ALn8VLqCiRR10                                      Stargazing
# 46  1XBYiRV30ykHw5f4wm6qEn                                NIGHTS LIKE THIS
# 47  3fgehc497TFqKH1zBL2YNK                              Heavy Is the Crown
# 48  6HrALJOMsfPCCbUo5cJCON                                        ESCAPATE
# 49  6Qyc6fS4DsZjB2mRW9DsQs                                            Iris
#
#     song_duration                                           song_url  \
# 0          251667  https://open.spotify.com/track/2plbrEY59IikOBg...
# 1          210373  https://open.spotify.com/track/6dOtVTDdiauQNBQ...
# 2          170887  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...
# 3          157279  https://open.spotify.com/track/5G2f63n7IPVPPjf...
# 4          175459  https://open.spotify.com/track/2HRqTpkrJO5ggZy...
# 5          218423  https://open.spotify.com/track/0WbMK4wrZ1wFSty...
# 6          256000  https://open.spotify.com/track/1Es7AUAhQvapIco...
# 7          195824  https://open.spotify.com/track/6WatFBLVB0x077x...
# 8          186365  https://open.spotify.com/track/2tHwzyyOLoWSFqY...
# 9          180304  https://open.spotify.com/track/3xkHsmpQCBMytMJ...
# 10         211978  https://open.spotify.com/track/2262bWmqomIaJXw...
# 11         171869  https://open.spotify.com/track/1UHS8Rf6h5Ar3CD...
# 12         261466  https://open.spotify.com/track/3QaPy1KgI7nu9FJ...
# 13         224022  https://open.spotify.com/track/0Sr7ssScx54yxdM...
# 14         171291  https://open.spotify.com/track/5fZJQrFKWQLb7Fp...
# 42               91  2024-10-11T12:30:50Z  5JjnoGJyOxfSZUZtk2rRwZ
# 43               90  2024-10-11T12:30:50Z  2Z1gnUf3nbn6DtwZSUIH54
# 44               90  2024-10-11T12:30:50Z  1NAmidJlEaVgA3MpcPFYGq
# 45               90  2024-10-11T12:30:50Z  3VNxRarx9HUI5w7DHv0TBj
# 46               88  2024-10-11T12:30:50Z  63IolVUykZCHMlu2zu9jHS
# 47               88  2024-10-11T12:30:50Z  3Su6Sgi0YjcUFuCzjLKYYq
# 48               86  2024-10-11T12:30:50Z  27GWSFRITD8JJcSGMgEfTN
# 49               87  2024-10-11T12:30:50Z  4UMjBXcRqIgMZ1XumU2x5T
#
#                                             artist_id
# 0      1HY2Jd0NmPuamShAr6KMms, 0du5cEVh5yTK9QJze8zA0C
# 1                              6qqNVTkY8uBg9cP3Jd7DAH
# 2                              1oSPZhvZMIrWW5I41kPkkY
# 3                              74KM79TiuVKeVCqs8QtB0B
# 4                              74KM79TiuVKeVCqs8QtB0B
# 5                              7GlBOeep6PqTfFi59PTUUN
# 6      1Xyo4u8uXC1ZmMpatF05PJ, 699OTQXzgjhIYAHMy9RyPD
# 7                              790FomKkXshlbRYZFtlgla
# 8                              74KM79TiuVKeVCqs8QtB0B
# 9                              22wbnEMDvgVIAGdFeek6ET
# 10                             1iCnM8foFssWlPRLfAbIwo
# 11                             74KM79TiuVKeVCqs8QtB0B
# 12                             6qqNVTkY8uBg9cP3Jd7DAH
# 13     3E12tRURRvPfHz0hAMCFYc, 54seKvtsZauR1iauN0ptpo
# 14                             3y2cIKLjiOlp1Np37WiUdH
# 15                             77SW9BnxLY8rJ0RciFqkHh
# 16                             6XyY86QOPPrYVGvF9ch6wz
# 17                             2FXC3k01G6Gw61bmprjgqS
# 18                             4tuJ0bMpJh08umKkEXKUI5
# 19  1Xyo4u8uXC1ZmMpatF05PJ, 250b0Wlc5Vk0CoUsaCY84M...
# 20                             7Ln80lUS6He07XvHI8qqHH
# 21                             5L1lO4eRHmJ7a0Q6csE5cT
# 22                             33qOK5uJ8AR2xuQQAhHump
# 23     0Y5tJX1MQlPlqiwlOH1tJY, 699OTQXzgjhIYAHMy9RyPD
# 24                             5eumcnUkdmGvkvcsx1WFNG
# 25                             7CvTknweLr9feJtRGrpDBy
# 26     246dkjvS1zLTtiykXe5h60, 4oUHIQIBe0LHzYfvXNW4QM
# 27                             5HK6QtizXJzCmoYTkvFRik
# 28     7CvTknweLr9feJtRGrpDBy, 1Yj5Xey7kTwvZla8sqdsdE
# 29     25uiPmTg16RbhZWAqwLBy5, 6qqNVTkY8uBg9cP3Jd7DAH
# 30                             5p9HO3XC5P3BLxJs5Mtrhm
# 31                             66CXWjxzNUsdJxJ2JdwvnR
# 32                             4gvjmrtzydbMpyJaXUtwvP
# 33                             7GlBOeep6PqTfFi59PTUUN
# 34     4V8LLVI7PbaPR0K2TGSxFF, 1U1el3k54VvEUzo3ybLPlM
# 35     12GqGscKJx3aE4t07u7eVZ, 6pV5zH2LzjOUHaAvENdMMa
# 36                             6ltzsmQQbmdoHHbLZ4ZN25
# 37     5eumcnUkdmGvkvcsx1WFNG, 12GqGscKJx3aE4t07u7eVZ
# 38     6HaGTQPmzraVmaVxvz6EUc, 3MdXrJWsbVzdn6fe5JYkSQ
# 39     2LRoIwlKmHjgvigdNGBHNo, 7jAs1uPnpfNmT6e5qtEPxq
# 40  1Yj5Xey7kTwvZla8sqdsdE, 7CvTknweLr9feJtRGrpDBy...
# 41                             0PCCGZ0wGLizHt2KZ7hhA2
# 42                             2YZyLoL8N0Wb9xBt1NhZWg
# 43                             1WaFQSHVGZQJTbf0BdxdNo
# 44                             06HL4z0CvFAxyc27GXpf02
# 45                             3bO19AOone0ubCsfDXDtYt
# 46                             2tIP7SsRs7vjIcLrU85W8J
# 47                             6XyY86QOPPrYVGvF9ch6wz
# 48     5eumcnUkdmGvkvcsx1WFNG, 2rmkQLzj0k4nZdQehOUByO
# 49                             2sil8z5kiy4r76CRTXxBCA

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added']).dt.date

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_url         50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     object
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_url         50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     datetime64[ns]
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
song_df.head()
# Out:
#                   song_id           song_name  song_duration  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile         251667
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER         210373
# 2  7tI8dRuH2Yc6RuoTjxo4dU                 Who         170887
# 3  5G2f63n7IPVPPjfNIGih7Q               Taste         157279
# 4  2HRqTpkrJO5ggZyyK6NPWz            Espresso         175459
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...              100
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...               98
# 2  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...               93
# 3  https://open.spotify.com/track/5G2f63n7IPVPPjf...               95
# 4  https://open.spotify.com/track/2HRqTpkrJO5ggZy...               87
#
#   song_added                album_id  \
# 0 2024-10-11  10FLjwfpbxLmW8c25Xyc2N
# 1 2024-10-11  7aJuG4TFXa2hmE4z1yxc3n
# 2 2024-10-11  15XcLhiVMlSOipUddTNDnr
# 3 2024-10-11  3iPSVi54hsacKKl1xIR2eH
# 4 2024-10-11  3iPSVi54hsacKKl1xIR2eH
#
#                                         artist_id
# 0  1HY2Jd0NmPuamShAr6KMms, 0du5cEVh5yTK9QJze8zA0C
# 1                          6qqNVTkY8uBg9cP3Jd7DAH
# 2                          1oSPZhvZMIrWW5I41kPkkY
# 3                          74KM79TiuVKeVCqs8QtB0B
# 4                          74KM79TiuVKeVCqs8QtB0B
